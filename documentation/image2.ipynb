# %%
# !pip install cairosvg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.1/75.1 kB 3.9 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

lettres = {
    'A': [
        "0110",
        "1001",
        "1111",
        "1001",
        "1001"
    ],
    'B': [
        "1110",
        "1001",
        "1110",
        "1001",
        "1110"
    ],
    'C': [
        "0111",
        "1000",
        "1000",
        "1000",
        "0111"

    ],

    'D': [
        "1110",
        "1001",
        "1001",
        "1001",
        "1110"
    ],
    'E': [
        "1111",
        "1000",
        "1110",
        "1000",
        "1111"
    ],
    'F': [
        "1111",
        "1000",
        "1110",
        "1000",
        "1000"
    ],
    'G': [
        "0110",
        "1000",
        "1011",
        "1001",
        "0110"
    ],
    'H': [
        "1001",
        "1001",
        "1111",
        "1001",
        "1001"
    ],
    'I': [
        "0111",
        "0010",
        "0010",
        "0010",
        "0111"
    ],
    'J': [
        "0001",
        "0001",
        "0001",
        "1001",
        "0110"
    ],
    'K': [
        "1001",
        "1010",
        "1100",
        "1010",
        "1001"
    ],
    'L': [
        "1000",
        "1000",
        "1000",
        "1000",
        "1111"
    ],
    'M': [
        "10001",
        "11011",
        "10101",
        "10001",
        "10001"
    ],
    'N': [
        "1001",
        "1101",
        "1011",
        "1001",
        "1001"
    ],
    'O': [
        "0110",
        "1001",
        "1001",
        "1001",
        "0110"
    ],
    'P': [
        "1110",
        "1001",
        "1110",
        "1000",
        "1000"
    ],
    'Q': [
        "0110",
        "1001",
        "1001",
        "1011",
        "0111"
    ],
    'R': [
        "1110",
        "1001",
        "1110",
        "1010",
        "1001"
    ],
    'S': [
        "0111",
        "1000",
        "0110",
        "0001",
        "1110"
    ],
    'T': [
        "11111",
        "00100",
        "00100",
        "00100",
        "00100"
    ],
    'U': [
        "1001",
        "1001",
        "1001",
        "1001",
        "0110"
    ],
    'V': [
        "10001",
        "10001",
        "01010",
        "01010",
        "00100"
    ],
    'W': [
        "10001",
        "10101",
        "10101",
        "11011",
        "10001"
    ],
    'X': [
        "10001",
        "01010",
        "00100",
        "01010",
        "10001"
    ],
    'Y': [
        "10001",
        "01010",
        "00100",
        "00100",
        "00100"
    ],
    'Z': [
        "1111",
        "0001",
        "0010",
        "0100",
        "1111"
    ]
}
def afficher_lettre_en_pixels_avec_quadrillage(lettre):
      fig, ax = plt.subplots()

    # Créer un tableau avec les valeurs de la lettre
      tableau_lettre = np.array([[int(pixel) for pixel in ligne] for ligne in lettre])

    # Créer une image en utilisant imshow
      ax.imshow(tableau_lettre, cmap='binary', vmin=0, vmax=1)

    # Ajouter des lignes de quadrillage
      ax.set_xticks(np.arange(-0.5, len(lettre[0]) - 0.5, 1), minor=True)
      ax.set_yticks(np.arange(-0.5, len(lettre) - 0.5, 1), minor=True)
      #ax.grid(which='minor', color='black', linestyle='-', linewidth=2)

      plt.show()


mot = input("Enter your name : ")

# Parcourt chaque lettre dans le mot et affiche chaque lettre sous forme de pixels
for lettre in mot.upper():  # Convertit toutes les lettres en majuscules
    print()
    print(lettre)
    print()
    if lettre in lettres:
              afficher_lettre_en_pixels_avec_quadrillage(lettres[lettre])
    else:
        print("Lettre non prise en charge:", lettre)
# Out:
# Enter your name : a
#
# A
