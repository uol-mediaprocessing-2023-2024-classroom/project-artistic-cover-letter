# %%
import cv2
from matplotlib import pyplot as plt

# %%
# Load the cascade (front face), from opencv github
face_cascade_frontal = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
# Read the input image
img = cv2.imread('test1.jpeg')

# Convert into grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Detect faces
faces = face_cascade_frontal.detectMultiScale(gray, 1.1, 5)

# Draw rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

# Display the output
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Face detection for a group')
plt.axis('off');

# %%
img = cv2.imread('test.jpg')

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

#scaleFactor=1.1
faces = face_cascade_frontal.detectMultiScale(gray, 1.1, 5)

for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Face detection for one person')
plt.axis('off');

# %%
img = cv2.imread('test.jpg')

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

#scaleFactor=1.9
faces = face_cascade_frontal.detectMultiScale(gray, 1.9, 5)

for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Face detection for one person, hight scaleFactor')
plt.axis('off');

# %%
img = cv2.imread('test.jpg')

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

#scaleFactor=1.01
faces = face_cascade_frontal.detectMultiScale(gray, 1.01, 5)

for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Face detection for one person, low scaleFactor')
plt.axis('off');
